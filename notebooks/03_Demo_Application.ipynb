# %% [markdown]
# # Demo Application - Customized Image Generation
#
# **Phan Đức Thành Phát (23521149)** - Integration & Demo
#
# Gradio demo application cho style transfer.
#
# **Lưu ý**: Cần có inference pipeline hoàn chỉnh trước khi tạo demo.

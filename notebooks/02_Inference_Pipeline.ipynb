# %% [markdown]
# # Inference Pipeline - Customized Image Generation
#
# **Phan Đức Thành Phát (23521149)** - Integration & Demo
#
# Inference với LoRA để tạo ảnh style transfer.
#
# **Lưu ý**: Cần có trained LoRA models từ Minh Quốc trước khi chạy inference này.

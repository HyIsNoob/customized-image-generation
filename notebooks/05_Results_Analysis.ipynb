# %% [markdown]
# # Results Analysis - Customized Image Generation
#
# **Nguyễn Khang Hy (2352662)** - Team Lead
#
# Phân tích và so sánh kết quả giữa các phong cách, tổng hợp báo cáo.
#
# **Lưu ý**: Cần có kết quả từ notebook 04_Evaluation_Metrics.ipynb trước khi chạy analysis này.
